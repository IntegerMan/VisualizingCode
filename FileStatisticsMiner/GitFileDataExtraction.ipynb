# %%
# Install libraries not present in Anaconda
# %pip install pydriller
# Out:
# Requirement already satisfied: pydriller in c:\users\matte\anaconda3\lib\site-packages (2.0)
# Requirement already satisfied: pytz in c:\users\matte\anaconda3\lib\site-packages (from pydriller) (2021.1)
# Requirement already satisfied: gitpython in c:\users\matte\anaconda3\lib\site-packages (from pydriller) (3.1.24)
# Requirement already satisfied: lizard in c:\users\matte\anaconda3\lib\site-packages (from pydriller) (1.17.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\matte\anaconda3\lib\site-packages (from gitpython->pydriller) (3.7.4.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\matte\anaconda3\lib\site-packages (from gitpython->pydriller) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\matte\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython->pydriller) (5.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports
from pydriller import Repository

account = 'IntegerMan'
repository = 'OpenRA'

path = 'https://github.com/' + account + '/' + repository

print('Using repository ' + path)
# Out:
# Using repository https://github.com/IntegerMan/OpenRA

# %%
repo = Repository(path)

repo_commits = repo.traverse_commits()

# %%
commits = []

for commit in repo_commits:
    for f in commit.modified_files:
        record = {
            'hash': commit.hash,
            'message': commit.msg,
            'author_name': commit.author.name,
    #       'author_email': commit.author.email,
            'author_date': commit.author_date,
    #       'author_tz': commit.author_timezone,
    #      'committer_name': commit.committer.name,
    #      'committer_email': commit.committer.email,
    #      'committer_date': commit.committer_date,
    #      'committer_tz': commit.committer_timezone,
            'in_main': commit.in_main_branch,
            'is_merge': commit.merge,
            'num_deletes': commit.deletions,
            'num_inserts': commit.insertions,
            'net_lines': commit.insertions - commit.deletions,
            'num_files': commit.files,
            'branches': ', '.join(commit.branches), # Comma separated list of branches the commit is found in
            'filename': f.filename,
            'old_path': f.old_path,
            'new_path': f.new_path,
            'project_name': commit.project_name,
            'project_path': commit.project_path, 
            'parents': ', '.join(commit.parents), # Comma separated list of parents
        }
        # Omitted: modified_files (list), project_path, project_name
        commits.append(record)

# %%
import pandas as pd

# Translate this list of commits to a Pandas data frame, then export it to CSV for analysis
df_commits = pd.DataFrame(commits)
df_commits.head()
# Out:
#                                        hash  \
# 0  b59ba43934a3a6837410db51cf60157cf854e52d
# 1  b59ba43934a3a6837410db51cf60157cf854e52d
# 2  b59ba43934a3a6837410db51cf60157cf854e52d
# 3  b59ba43934a3a6837410db51cf60157cf854e52d
# 4  b59ba43934a3a6837410db51cf60157cf854e52d
#
#                                              message author_name  \
# 0  openra first commit!\n\ngit-svn-id: svn://svn....      chrisf
# 1  openra first commit!\n\ngit-svn-id: svn://svn....      chrisf
# 2  openra first commit!\n\ngit-svn-id: svn://svn....      chrisf
# 3  openra first commit!\n\ngit-svn-id: svn://svn....      chrisf
# 4  openra first commit!\n\ngit-svn-id: svn://svn....      chrisf
#
#                  author_date  in_main  is_merge  num_deletes  num_inserts  \
# 0  2007-06-19 08:51:17+00:00     True     False            0         1350
# 1  2007-06-19 08:51:17+00:00     True     False            0         1350
# 2  2007-06-19 08:51:17+00:00     True     False            0         1350
# 3  2007-06-19 08:51:17+00:00     True     False            0         1350
# 4  2007-06-19 08:51:17+00:00     True     False            0         1350
#
#    net_lines  num_files branches           filename           old_path  \
# 0       1350         11    bleed        Blowfish.cs               None
# 1       1350         11    bleed             MM.DAT  MixBrowser\MM.DAT
# 2       1350         11    bleed  MixBrowser.csproj               None
# 3       1350         11    bleed        MixEntry.cs               None
# 4       1350         11    bleed         Program.cs               None
#
#                        new_path project_name  \
# 0        MixBrowser\Blowfish.cs       OpenRA
# 1             MixBrowser\MM.DAT       OpenRA
# 2  MixBrowser\MixBrowser.csproj       OpenRA
# 3        MixBrowser\MixEntry.cs       OpenRA
# 4         MixBrowser\Program.cs       OpenRA
#
#                                         project_path parents
# 0  C:\Users\MattE\AppData\Local\Temp\tmpsnu5cl6m\...
# 1  C:\Users\MattE\AppData\Local\Temp\tmpsnu5cl6m\...
# 2  C:\Users\MattE\AppData\Local\Temp\tmpsnu5cl6m\...
# 3  C:\Users\MattE\AppData\Local\Temp\tmpsnu5cl6m\...
# 4  C:\Users\MattE\AppData\Local\Temp\tmpsnu5cl6m\...

# %%
df_commits.to_csv(repository + '_FileCommits.csv')
